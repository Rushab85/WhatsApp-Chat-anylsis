# %%
import re
import pandas as pd
import numpy as np
import emoji
import plotly.express as px
from collections import Counter
import matplotlib.pyplot as plt
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
f = open("whatsapp_chat.txt", 'r', encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 16/04/24, 15:01 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 20/04/24, 10:44 - Disappearing messages were turned off. Tap to change.
# 20/04/24, 10:44 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 20/04/24, 22:19 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 21/04/24, 10:54 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 21/04/24, 22:32 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 27/04/24, 10:14 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 27/04/24, 22:00 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 28/04/24, 13:00 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 28/04/24, 14:57 - Eduonix: Hi DS June 2023
#
# Here is the recording of yesterday's session :- https://us02web.zoom.us/rec/share/wTrriVTkBnSJh9CDf9zU1FQ16K9RxR0XkOc0td0fFpHQoIm2Dcu5NdEGGYwrSQCp.-uBl6hMQc9BRLYrs
#
# Kindly go through it before the upcoming session.
#
# Regards,
# 28/04/24, 22:30 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 04/05/24, 14:20 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 05/05/24, 10:50 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 05/05/24, 21:44 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 11/05/24, 15:12 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 11/05/24, 22:14 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 12/05/24, 13:03 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 12/05/24, 22:51 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 18/05/24, 10:10 - Eduonix: This message was deleted
# 18/05/24, 10:56 - Eduonix: Hello Students,
#
# Today's and tomorrow's session has been cancelled due to some unforeseeable circumstances.
#
# We apologies for the inconveniences caused.
#
# Regards,
# Team Eduonix
# 20/05/24, 10:08 - Eduonix: Hello Learner,
#
# Due to elections, we are not available today so if there is any query kindly drop a message we will get it solved by tomorrow EOD.
#
# Regards,
# Eduonix
# 25/05/24, 10:21 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 25/05/24, 22:29 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 26/05/24, 10:27 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 26/05/24, 20:14 - Eduonix: Session has been hosted
# 26/05/24, 20:14 - Eduonix: Join ASAP
# 26/05/24, 22:06 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 26/05/24, 22:39 - Rushab Joshi: Hlo
# 26/05/24, 22:39 - Rushab Joshi: How many months will the video record be available?
# 26/05/24, 22:40 - Rushab Joshi: For preparation interview
# 29/05/24, 11:47 - Eduonix: Hello Rushabh
# 29/05/24, 11:47 - Rushab Joshi: Hlo
# 29/05/24, 11:47 - Rushab Joshi: Plz  help me...
# 29/05/24, 11:47 - Eduonix: They shall be available, but just in case you don't get to access the issue, you can always approach us
# 29/05/24, 11:48 - Rushab Joshi: Ok
# 29/05/24, 11:48 - Rushab Joshi: And I want give interview  after  15 days
# 29/05/24, 11:48 - Rushab Joshi: Can I give?
# 29/05/24, 11:50 - Eduonix: Yes sure
# 29/05/24, 11:51 - Eduonix: Kindly inform us 2 days prior to what date and time you need
# 29/05/24, 11:51 - Eduonix: You can give your mock interview from monday to Saturday, 12 pm to 4 pm
# 29/05/24, 11:51 - Rushab Joshi: Ok
# 29/05/24, 11:51 - Rushab Joshi: Thanks
# 29/05/24, 11:52 - Rushab Joshi: And can u review  my resume
# 29/05/24, 11:53 - Rushab Joshi: And tell me mistake ?
# 29/05/24, 13:20 - Eduonix: yes sure, send your resume
# 29/05/24, 13:21 - Rushab Joshi: https://docs.google.com/document/d/1V0luEuA5KwHFiY4XchdynWEeEGNSYGTEGhWY6Y0UW8Y/edit?usp=drivesdk
# 31/05/24, 11:14 - Rushab Joshi: Did u check?
# 01/06/24, 10:35 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 02/06/24, 11:54 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 02/06/24, 13:24 - Eduonix: Hi Rushabh
# 02/06/24, 13:24 - Eduonix: I have forwarded your Resume
# 02/06/24, 13:30 - Rushab Joshi: Ok
# 02/06/24, 22:38 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 08/06/24, 11:08 - Eduonix: This message was deleted
# 08/06/24, 13:24 - Eduonix: This message was deleted
# 08/06/24, 13:25 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 08/06/24, 13:41 - Rushab Joshi: ?
# 09/06/24, 12:52 - Eduonix: Hi DS June 23,
#
# A gentle reminder for today's session at 8:00 pm
#
# Link- https://us02web.zoom.us/meeting/register/tZAuceihpjovH9G5-GjKU_k_lDZY8-Abs_1c
# Meeting ID- 84361981555
#
# Regards,
# 14/06/24, 13:20 - Eduonix: Dear Students,
#
# Hope you're well!
#
# We're excited to announce our new query system to streamline communication. Please take note:
#
# 1. **Effective Date**: Starting today, 12th June 2024, submit all non-academic inquiries through our query forum.
#
# 2. **Non-Academic Inquiries**: Only queries submitted via the query forum will be accepted. No more calls, WhatsApp, or emails for these.
#
# 3. **Academic Inquiries**: Use Microsoft Teams for academic queries and raise a ticket after posting your doubts. No other queries on Teams will be responded to.
#
# 4. **Video Guide**: Watch this video to learn how to use the new system: https://drive.google.com/file/d/1XgKvh5GeNtneBoYYZeK3JQ8t5udczhuC/view?usp=sharing
#
# 5. **Enforcement**: Queries via WhatsApp, phone calls, or outside Teams for academic issues will not be considered.
#
# 6. **Reminder Desk**: Our Support Contact is now our Reminder Desk, sending only session reminders. No other queries will be addressed here.
#
# Thanks for your cooperation!
#
# Best,
# Team Eduonix
# 15/06/24, 13:13 - Eduonix: Hi Learner,
#
# A gentle reminder for today's *session at 7:00 pm.*
#
# Here is the zoom link and meeting id-
# Link- https://us02web.zoom.us/meeting/register/tZwkcO2vrjwtHdNQIf3pTQj6bX0-buEpecH5
#
# Meeting ID- 88974707777
#
# Regards,
# 15/06/24, 19:44 - Eduonix: Dear Students,
#
# Hope you're doing great!
#
# We’re excited to announce that the placement process starts this weekend! Update your CVs with all relevant projects and details from the program.
#
# We’ll begin mock interviews & tests next weekend, so use this time wisely to prepare and kickstart your Data Science career.Also, we will be covering your Excel module over the upcoming weekends.
# Your final Capstone Projectis as shared with you will lead to your certification.
#
# Prepare well to clear your Capstone, tests, and mocks promptly!
#
# Best,
# Team Eduonix
# 15/06/24, 23:29 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 16/06/24, 13:21 - Eduonix: Hi Learner,
#
# A gentle reminder for today's *session at 7:00 pm.*
#
# Here is the zoom link and meeting id-
# Link- https://us02web.zoom.us/meeting/register/tZwkcO2vrjwtHdNQIf3pTQj6bX0-buEpecH5
#
# Meeting ID- 88974707777
#
# Regards,
# 16/06/24, 22:15 - Eduonix: Hello DS June 2023,
#
# Below mentioned is the feedback form. Form Link - https://forms.gle/k9b4Jk6R9PDG9uHR6
#
# Make sure you all are filling this as this is important for your attendance.
#
# Thank You.
# 18/06/24, 21:46 - Eduonix: <Media omitted>
# 19/06/24, 06:53 - Rushab Joshi: Can u tell me fix date?
# because  I off to out off city..21 to 25
# 19/06/24, 06:53 - Rushab Joshi: 🙏
# 20/06/24, 12:00 - Eduonix: Hello Learner,
#
# This weekend there will your python test.
#
# Regards,
# Eduonix
# 20/06/24, 14:04 - Rushab Joshi: Hlo
# 21/06/24, 20:54 - Eduonix: Dear Students,
#
# This is to inform you that the exams will be conducted this coming weekend. Please take note of the following details:
#
# **Exam Date:** Sunday, 23rd June 2024
# **Exam Time:** 6:00 PM
# **Test Topic:** Python Module
#
# The necessary links for the exam will be shared soon. Please prepare accordingly.
#
# Wishing you all the best for your exams.
#
# Sincerely,
# Eduonix
# 22/06/24, 16:46 - Eduonix: Hi Learner,
#
# A gentle reminder for today's *session at 7:00 pm.*
#
# Here is the zoom link and meeting id-
# Link- https://us02web.zoom.us/meeting/register/tZwkcO2vrjwtHdNQIf3pTQj6bX0-buEpecH5
#
# Meeting ID- 88974707777
#
# Regards,
# 22/06/24, 19:08 - Eduonix: The session will start at 7:30 pm
# 23/06/24, 12:49 - Eduonix: Hi learners,
#
# Kindly note that the exam is postponed as many of the learners requested to want more time for presentations.
#
# Please note that the exam will be scheduled on weekdays.
#
# Regards,

# %%
from datetime import datetime

def StartWithDateAndTime(s):
    print(f"{datetime.now()}: {s}")

# %%
def FindAuthor(s):
    s = s.split(" : ")
    if len(s) == 2:
        return True
    else:
        return False

# %%
def getDataPoint(line):
    splitline = line.split(" - ")
    dateTime = splitLine[0]
    date, time = dateTime.split(" _ " )
    message = ' '.join(splitMessage[1:])
    if FindAuthor(message):
        splitMessage = message.split(' : ')
        author = splitMessage[0]
        message = ' '.join(splitMessage[1:])
    else:
        author = None
    return date,time,autor,message

# %%
with open("whatsapp_chat.txt", 'r', encoding='utf-8') as f: # open with o 
    # Read the content of the file
    data = f.readlines()

# %%
# creat a DataFrame
df = pd.DataFrame(data, columns = [ "chat"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   chat    346 non-null    object
# dtypes: object(1)
# memory usage: 2.8+ KB

# %%
df.head(8)
# Out:
#                                                 chat
# 0  16/04/24, 15:01 - Messages and calls are end-t...
# 1  20/04/24, 10:44 - Disappearing messages were t...
# 2        20/04/24, 10:44 - Eduonix: Hi DS June 23,\n
# 3                                                 \n
# 4  A gentle reminder for today's session at 8:00 ...
# 5                                                 \n
# 6  Link- https://us02web.zoom.us/meeting/register...
# 7                          Meeting ID- 84361981555\n

# %%
df.shape
# Out:
# (346, 1)

# %%
df.tail()
# Out:
#                                                   chat
# 341  Kindly note that the exam is postponed as many...
# 342                                                 \n
# 343  Please note that the exam will be scheduled on...
# 344                                                 \n
# 345                                         Regards,\n

# %%
def FindAuthor(s):
    # Split the message to check if it contains an author
    s = s.split(": ")
    if len(s) == 2:
        return True
    else:
        return False

def StartWithDateAndTime(s):
    # Check if the string starts with a date and time format
    pattern = '^[0-9]{1,2}/[0-9]{1,2}/[0-9]{2}, [0-9]{1,2}:[0-9]{2} - '
    result = re.match(pattern, s)
    if result:
        return True
    return False

def getDataPoint(line):
    # Split the line into dateTime and message
    splitLine = line.split(" - ")
    dateTime = splitLine[0]
    date, time = dateTime.split(", ")
    message = ' '.join(splitLine[1:])
    
    if FindAuthor(message):
        splitMessage = message.split(": ")
        author = splitMessage[0]
        message = ' '.join(splitMessage[1:])
    else:
        author = None
    return date, time, author, message

# Read the WhatsApp chat data
with open("whatsapp_chat.txt", 'r', encoding='utf-8') as f:
    data = f.readlines()

# Initialize lists to store the parsed data
dates = []
times = []
authors = []
messages = []

# Parse each line in the chat data
for line in data:
    if StartWithDateAndTime(line):
        date, time, author, message = getDataPoint(line)
        dates.append(date)
        times.append(time)
        authors.append(author)
        messages.append(message)
    else:
        # If the line does not start with date and time, it's a continuation of the previous message
        messages[-1] += ' ' + line.strip()

# Create a DataFrame to store the parsed data
df = pd.DataFrame({
    "date": dates,
    "time": times,
    "author": authors,
    "message": messages
})

df.tail()

# Save the DataFrame to a CSV file for further analysis
df.to_csv('whatsapp_chat_data.csv', index=False)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#        date   time   author                                            message
# 0  16/04/24  15:01     None  Messages and calls are end-to-end encrypted. N...
# 1  20/04/24  10:44     None  Disappearing messages were turned off. Tap to ...
# 2  20/04/24  10:44  Eduonix  Hi DS June 23,\n  A gentle reminder for today'...
# 3  20/04/24  22:19  Eduonix  Hello DS June 2023,\n  Below mentioned is the ...
# 4  21/04/24  10:54  Eduonix  Hi DS June 23,\n  A gentle reminder for today'...

# %%
author_message_count = df['author'].value_counts()
print(author_message_count)
# Out:
# author
# Eduonix         52
# Rushab Joshi    19
# Name: count, dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])
daily_message_count = df.groupby(df['date'].dt.date).size()
print(daily_message_count)
# Out:
# date
# 2024-01-06     1
# 2024-02-06     5
# 2024-04-05     1
# 2024-04-16     1
# 2024-04-20     3
# 2024-04-21     2
# 2024-04-27     2
# 2024-04-28     3
# 2024-05-05     2
# 2024-05-18     2
# 2024-05-20     1
# 2024-05-25     2
# 2024-05-26     7
# 2024-05-29    16
# 2024-05-31     1
# 2024-06-14     1
# 2024-06-15     3
# 2024-06-16     2
# 2024-06-18     1
# 2024-06-19     2
# 2024-06-20     2
# 2024-06-21     1
# 2024-06-22     2
# 2024-06-23     1
# 2024-08-06     4
# 2024-09-06     1
# 2024-11-05     2
# 2024-12-05     2
# dtype: int64

# %%
text = ' '.join(df['message'].tolist())
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', width=800, height=400).generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Save the word cloud image
wordcloud.to_file("wordcloud.png")

# %%
df['message_length'] = df['message'].apply(len)
print(df[['author', 'message_length']].groupby('author').mean())
# Out:
#               message_length
# author
# Eduonix           170.826923
# Rushab Joshi       21.368421

# %%
from textblob import TextBlob
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# %%
df['sentiment'] = df['message'].apply(get_sentiment)    #Apply sentiment analyis

# %%
print(df[['author', 'sentiment']].groupby('author').mean())    #Display the average sentiment
# Out:
#               sentiment
# author
# Eduonix        0.242020
# Rushab Joshi   0.113158
